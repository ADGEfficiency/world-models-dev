# %%
import pandas as pd

raw = pd.read_csv('/Users/adam/world-models-experiments/memory-training/training.csv', header=None)

# %%
# %matplotlib inline
print(raw.shape)
raw.iloc[100:, 2].plot()
# Out:
# (2000, 4)
