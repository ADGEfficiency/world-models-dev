# %%
# plot the number of generations for each agent (one, two etc) versus final score (avg last 10?)

# %%
import numpy as np

# %%
f = np.loadtxt('/Users/adam/world-models-experiments/control/rewards.log')

# %%
import matplotlib.pyplot as plt

plt.plot(f[-100:])

# %%
plt.plot(f)

# %%
f
# Out:
# array([-80.30223512, -91.19905845, -77.20912167, -55.36882226,
#        -55.57853717, -86.07662947, -43.58068065, -27.57411344,
#         -2.62554605,  15.14528233,  21.3617733 ,  32.81794613,
#        -31.30905326,  73.76413019,  85.42155395,  28.91072519,
#        119.2838432 , 123.02982832, 137.553299  , 159.57582244,
#        159.79839956, 167.61504472, 169.2791793 , 220.64164172,
#        225.29503154, 237.17657311, 169.08886031, 255.32771876,
#        238.8654016 , 275.71294861, 284.07375533, 295.24955006,
#        329.54334587, 330.09300336, 336.06633168, 315.61540556,
#        317.51666637, 308.82906008, 298.05675218, 377.23530855,
#        351.5083034 , 388.56237707, 353.56518731, 403.16446121,
#        423.37400602, 435.95275437, 446.73027185, 424.92130544,
#        432.13903341, 459.96518904, 460.44636843, 443.9474136 ,
#        447.47267714, 474.22037188, 471.16950258, 484.56609779,
#        473.7011374 , 501.70553827, 510.14120212, 499.00623171,
# ...

# %%
from collections import defaultdict

res = defaultdict(list)
for gen in range(232):

    population_rewards = np.load('/Users/adam/world-models-experiments/control/generations/generation_{}/epoch-results.npy'.format(gen))

   #plt.hist(population_rewards)

    res['var'].append(np.var(population_rewards))

# %%
plt.plot(res['var'])
